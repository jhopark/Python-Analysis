# %%
# input data

import pandas as pd
data = pd.read_excel('2015_주택소유의식조사_MD.xlsx')

df = pd.DataFrame(data)
df.head()
# Out:
#    ID  SQ1   SQ2  SQ21  SQ3  SQ31     SQ4  SQ41  SQ42  A1  ...      D7  \
# 0   1    1  1980     3    2    28  201405  2014     5   1  ...       4
# 1   2    2  1981     3    2    39  201204  2012     4   2  ...       1
# 2   3    2  1977     3    1     9  199505  1995     5   2  ...  #NULL!
# 3   4    2  1993     2    2    27  201506  2015     6   3  ...       1
# 4   5    2  1973     4    1    24  200510  2005    10   2  ...  #NULL!
#
#        D8 DQ1 DQ2 DQ3 DQ4   DQ5a1   DQ5a2   DQ5a3        wt
# 0       2   1   4   4   4      서울      서초      서초  1.000000
# 1       5   2   4   2   1  #NULL!  #NULL!  #NULL!  1.000000
# 2  #NULL!   2   4   4   3      서울      강북      수유  0.857143
# 3       4   1   3   3   5      서울      성북      돈암  1.000000
# 4  #NULL!   2   2   2   1  #NULL!  #NULL!  #NULL!  1.454545
#
# [5 rows x 65 columns]

# %%
# exchange '#NULL' to None  

import numpy as np

data = df.replace('#NULL!', np.NaN)
data.head()
# Out:
#    ID  SQ1   SQ2  SQ21  SQ3  SQ31     SQ4  SQ41  SQ42  A1  ...   D7   D8  DQ1  \
# 0   1    1  1980     3    2    28  201405  2014     5   1  ...  4.0  2.0    1
# 1   2    2  1981     3    2    39  201204  2012     4   2  ...  1.0  5.0    2
# 2   3    2  1977     3    1     9  199505  1995     5   2  ...  NaN  NaN    2
# 3   4    2  1993     2    2    27  201506  2015     6   3  ...  1.0  4.0    1
# 4   5    2  1973     4    1    24  200510  2005    10   2  ...  NaN  NaN    2
#
#    DQ2  DQ3  DQ4  DQ5a1  DQ5a2  DQ5a3        wt
# 0    4    4    4     서울     서초     서초  1.000000
# 1    4    2    1    NaN    NaN    NaN  1.000000
# 2    4    4    3     서울     강북     수유  0.857143
# 3    3    3    5     서울     성북     돈암  1.000000
# 4    2    2    1    NaN    NaN    NaN  1.454545
#
# [5 rows x 65 columns]

# %%
## Check blank data

import missingno as msno
msno.matrix(data)

# %%
# exchange number to text
data.loc[data.SQ21==2, 'SQ21'] = '20대'
data.loc[data.SQ21==3, 'SQ21'] = '30대'
data.loc[data.SQ21==4, 'SQ21'] = '40대'
data.loc[data.SQ21==5, 'SQ21'] = '50대'
data.loc[data.SQ21==6, 'SQ21'] = '60대'

# exchange number to local
data.loc[data.SQ31== 1, 'SQ31'] = '종로구'
data.loc[data.SQ31== 2, 'SQ31'] = '중구'
data.loc[data.SQ31== 3, 'SQ31'] = '용산구'
data.loc[data.SQ31== 4, 'SQ31'] = '성동구'
data.loc[data.SQ31== 5, 'SQ31'] = '광진구'
data.loc[data.SQ31== 6, 'SQ31'] = '동대문'
data.loc[data.SQ31== 7, 'SQ31'] = '중랑구'
data.loc[data.SQ31== 8, 'SQ31'] = '성북구'
data.loc[data.SQ31== 9, 'SQ31'] = '강북구'
data.loc[data.SQ31== 10, 'SQ31'] = '도봉구'
data.loc[data.SQ31== 11, 'SQ31'] = '노원구'
data.loc[data.SQ31== 12, 'SQ31'] = '은평구'
data.loc[data.SQ31== 13, 'SQ31'] = '서대문'
data.loc[data.SQ31== 14, 'SQ31'] = '마포구'
data.loc[data.SQ31== 15, 'SQ31'] = '양천구'
data.loc[data.SQ31== 16, 'SQ31'] = '강서구'
data.loc[data.SQ31== 17, 'SQ31'] = '구로구'
data.loc[data.SQ31== 18, 'SQ31'] = '금천구'
data.loc[data.SQ31== 19, 'SQ31'] = '영등포'
data.loc[data.SQ31== 20, 'SQ31'] = '동작구'
data.loc[data.SQ31== 21, 'SQ31'] = '관악구'
data.loc[data.SQ31== 22, 'SQ31'] = '서초구'
data.loc[data.SQ31== 23, 'SQ31'] = '강남구'
data.loc[data.SQ31== 24, 'SQ31'] = '송파구'
data.loc[data.SQ31== 25, 'SQ31'] = '강동구'
data.loc[data.SQ31== 26, 'SQ31'] = '인천광역시 부평구'
data.loc[data.SQ31== 27, 'SQ31'] = '인천광역시 계양구'
data.loc[data.SQ31== 28, 'SQ31'] = '성남시 수정구'
data.loc[data.SQ31== 29, 'SQ31'] = '성남시 중원구'
data.loc[data.SQ31== 30, 'SQ31'] = '성남시 분당구'
data.loc[data.SQ31== 31, 'SQ31'] = '의정부시'
data.loc[data.SQ31== 32, 'SQ31'] = '안양시 만안구'
data.loc[data.SQ31== 33, 'SQ31'] = '안양시 동안구'
data.loc[data.SQ31== 34, 'SQ31'] = '부천시 원미구'
data.loc[data.SQ31== 35, 'SQ31'] = '부천시 소사구'
data.loc[data.SQ31== 36, 'SQ31'] = '부천시 오정구'
data.loc[data.SQ31== 37, 'SQ31'] = '광명시'
data.loc[data.SQ31== 38, 'SQ31'] = '고양시 덕양구'
data.loc[data.SQ31== 39, 'SQ31'] = '고양시 일산동구'
data.loc[data.SQ31== 40, 'SQ31'] = '고양시 일산서구'
data.loc[data.SQ31== 41, 'SQ31'] = '과천시'
data.loc[data.SQ31== 42, 'SQ31'] = '구리시'
data.loc[data.SQ31== 43, 'SQ31'] = '남양주시'
data.loc[data.SQ31== 44, 'SQ31'] = '군포시'
data.loc[data.SQ31== 45, 'SQ31'] = '의왕시'
data.loc[data.SQ31== 46, 'SQ31'] = '하남시'
data.loc[data.SQ31== 47, 'SQ31'] = '용인시 기흥구'
data.loc[data.SQ31== 48, 'SQ31'] = '용인시 수지구'
data.loc[data.SQ31== 49, 'SQ31'] = '김포시'
data.loc[data.SQ31== 50, 'SQ31'] = '양주시'

# 
data.loc[data.A1==1, 'A1'] = '가구주'
data.loc[data.A1==2, 'A1'] = '배우자'
data.loc[data.A1==3, 'A1'] = '자녀'
data.loc[data.A1==4, 'A1'] = '가구주 또는 가구주 배우자의 부모'
data.loc[data.A1==5, 'A1'] = '형제, 자매, 남매'
data.loc[data.A1==6, 'A1'] = '혈연관계 친척'
data.loc[data.A1==7, 'A1'] = '가족 또는 친척이 아닌 동거인'
data.loc[data.A1==8, 'A1'] = '기타'

data.loc[data.A3==1, 'A3'] = '100만원 이하'
data.loc[data.A3==2, 'A3'] = '101~200만원 이하'
data.loc[data.A3==3, 'A3'] = '201~300만원 이하'
data.loc[data.A3==4, 'A3'] = '301~400만원 이하'
data.loc[data.A3==5, 'A3'] = '401~500만원 이하'
data.loc[data.A3==6, 'A3'] = '501~600만원 이하'
data.loc[data.A3==7, 'A3'] = '601~700만원 이하'
data.loc[data.A3==8, 'A3'] = '701~800만원 이하'
data.loc[data.A3==9, 'A3'] = '801~900만원 이하'
data.loc[data.A3==10, 'A3'] = '901~1천만원 이하'
data.loc[data.A3==11, 'A3'] = '1천만원 초과'

data.loc[data.B1==1, 'B1'] = '아파트'
data.loc[data.B1==2, 'B1'] = '다세대·연립'
data.loc[data.B1==3, 'B1'] = '다가구주택'
data.loc[data.B1==4, 'B1'] = '단독주택'
data.loc[data.B1==5, 'B1'] = '오피스텔'
data.loc[data.B1==6, 'B1'] = '주상복합'
data.loc[data.B1==7, 'B1'] = '상가주택'
data.loc[data.B1==8, 'B1'] = '점포주택'
data.loc[data.B1==9, 'B1'] = '고시원'
data.loc[data.B1==10, 'B1'] = '기숙사'
data.loc[data.B1==11, 'B1'] = '기타'

data.loc[data.B2==1, 'B2'] = '18~33m²(10평) 이하'
data.loc[data.B2==2, 'B2'] = '34~60m²(18평) 이하'
data.loc[data.B2==3, 'B2'] = '61~80m²(24평) 이하'
data.loc[data.B2==4, 'B2'] = '81~105m²(32평) 이하'
data.loc[data.B2==5, 'B2'] = '106~153m²(48평) 이하'
data.loc[data.B2==6, 'B2'] = '159~198m²(60평) 이하'
data.loc[data.B2==7, 'B2'] = '198m²(60평) 초과'

data.loc[data.B3==1, 'B3'] = '자가'
data.loc[data.B3==2, 'B3'] = '가족소유의 주택'
data.loc[data.B3==3, 'B3'] = '전세'
data.loc[data.B3==4, 'B3'] = '보증금 있는 월세'
data.loc[data.B3==5, 'B3'] = '보증금 없는 월세'
data.loc[data.B3==6, 'B3'] = '공공임대주택'
data.loc[data.B3==7, 'B3'] = '무상'
data.loc[data.B3==8, 'B3'] = '기타'

data.loc[data.B4==1, 'B4'] = '1억 미만'
data.loc[data.B4==2, 'B4'] = '1억~3억 미만'
data.loc[data.B4==3, 'B4'] = '3~5억 미만'
data.loc[data.B4==4, 'B4'] = '5~7억 미만'
data.loc[data.B4==5, 'B4'] = '7~10억 미만'
data.loc[data.B4==6, 'B4'] = '10~15억 미만'
data.loc[data.B4==7, 'B4'] = '15~20억 미만'
data.loc[data.B4==8, 'B4'] = '20억 이상'

data.loc[data.B51==1, 'B51'] = '없음'
data.loc[data.B51==2, 'B51'] = '500만원 미만'
data.loc[data.B51==3, 'B51'] = '500~1천만원 미만'
data.loc[data.B51==4, 'B51'] = '1~5천만원 미만'
data.loc[data.B51==5, 'B51'] = '5천만~1억원 미만'
data.loc[data.B51==6, 'B51'] = '1억~2억원 미만'
data.loc[data.B51==7, 'B51'] = '2억~3억원 미만'
data.loc[data.B51==8, 'B51'] = '3억~5억원 미만'
data.loc[data.B51==9, 'B51'] = '5억~7억원 미만'
data.loc[data.B51==10, 'B51'] = '7억~10억원 미만'
data.loc[data.B51==11, 'B51'] = '10억원 초과'


data.loc[data.B52==1, 'B52'] = '없음'
data.loc[data.B52==2, 'B52'] = '30만원 미만'
data.loc[data.B52==3, 'B52'] = '30~50만원 미만'
data.loc[data.B52==4, 'B52'] = '50~70만원 미만'
data.loc[data.B52==5, 'B52'] = '70~100만원 미만'
data.loc[data.B52==6, 'B52'] = '100~150만원 미만'
data.loc[data.B52==7, 'B52'] = '150~200만원 미만'
data.loc[data.B52==8, 'B52'] = '200~300만원 미만'
data.loc[data.B52==9, 'B52'] = '300만원 초과'

data.loc[data.C1==1, 'C1'] = '없음'
data.loc[data.C1==2, 'C1'] = '있음'

data.loc[data.C111==1,'C111'] = '서울'
data.loc[data.C111==2,'C111'] = '경기,인천'
data.loc[data.C111==3,'C111'] = '비수도권'

data.loc[data.C112==1,'C112']= '서울'
data.loc[data.C112==2,'C112']= '경기,인천'
data.loc[data.C112==3,'C112']= '비수도권'

data.loc[data.C112==1,'C113']= '서울'
data.loc[data.C112==2,'C113']= '경기,인천'
data.loc[data.C112==3,'C113']= '비수도권'

data.loc[data.C121==1, 'C121'] = '1채'
data.loc[data.C121==2, 'C121'] = '2채'
data.loc[data.C121==3, 'C121'] = '3채'
data.loc[data.C121==4, 'C121'] = '4채'
data.loc[data.C121==5, 'C121'] = '5채 이상'

data.loc[data.C122==1, 'C122'] = '1채'
data.loc[data.C122==2, 'C122'] = '2채'
data.loc[data.C122==3, 'C122'] = '3채'
data.loc[data.C122==4, 'C122'] = '4채'
data.loc[data.C122==5, 'C122'] = '5채 이상'

data.loc[data.C123==1, 'C123'] = '1채'
data.loc[data.C123==2, 'C123'] = '2채'
data.loc[data.C123==3, 'C123'] = '3채'
data.loc[data.C123==4, 'C123'] = '4채'
data.loc[data.C123==5, 'C123'] = '5채 이상'

data.loc[data.C3==1, 'C3'] = '부동산이 낫다'
data.loc[data.C3==2, 'C3'] = '금융자산이 낫다'
data.loc[data.C3==3, 'C3'] = '잘 모름'

data.loc[data.D51==1, 'D51'] = '고향 등 지역의 익숙함, 친근함'
data.loc[data.D51==2, 'D51'] = '적절한 주택 가격'
data.loc[data.D51==3, 'D51'] = '필요한 주택 크기'
data.loc[data.D51==4, 'D51'] = '주택 구조, 연령, 난방설비 등 성능'
data.loc[data.D51==5, 'D51'] = '본인 또는 배우자의 직장과의 접근성'
data.loc[data.D51==6, 'D51'] = '편리한 대중교통'
data.loc[data.D51==7, 'D51'] = '자동차 이용 편리'
data.loc[data.D51==8, 'D51'] = '자녀의 교육 또는 보육 환경'
data.loc[data.D51==9, 'D51'] = '조용한 주거 지역'
data.loc[data.D51==10, 'D51'] = '편의시설 이용과 가까워서'
data.loc[data.D51==11, 'D51'] = '문화·여가시설(공연, 전시 등) 이용'
data.loc[data.D51==12, 'D51'] = '부모님, 자녀 등 가족과 가까워서'
data.loc[data.D51==13, 'D51'] = '자연환경(녹지, 하천 등)이 좋아서'
data.loc[data.D51==14, 'D51'] = '기타'

data.loc[data.D5101==1, 'D5101'] = '고향 등 지역의 익숙함, 친근함'
data.loc[data.D5101==2, 'D5101'] = '적절한 주택 가격'
data.loc[data.D5101==3, 'D5101'] = '필요한 주택 크기'
data.loc[data.D5101==4, 'D5101'] = '주택 구조, 연령, 난방설비 등 성능'
data.loc[data.D5101==5, 'D5101'] = '본인 또는 배우자의 직장과의 접근성'
data.loc[data.D5101==6, 'D5101'] = '편리한 대중교통'
data.loc[data.D5101==7, 'D5101'] = '자동차 이용 편리'
data.loc[data.D5101==8, 'D5101'] = '자녀의 교육 또는 보육 환경'
data.loc[data.D5101==9, 'D5101'] = '조용한 주거 지역'
data.loc[data.D5101==10, 'D5101'] = '편의시설 이용과 가까워서'
data.loc[data.D5101==11, 'D5101'] = '문화·여가시설(공연, 전시 등) 이용'
data.loc[data.D5101==12, 'D5101'] = '부모님, 자녀 등 가족과 가까워서'
data.loc[data.D5101==13, 'D5101'] = '자연환경(녹지, 하천 등)이 좋아서'
data.loc[data.D5101==14, 'D5101'] = '기타'

data.loc[data.D5102==1, 'D5102'] = '고향 등 지역의 익숙함, 친근함'
data.loc[data.D5102==2, 'D5102'] = '적절한 주택 가격'
data.loc[data.D5102==3, 'D5102'] = '필요한 주택 크기'
data.loc[data.D5102==4, 'D5102'] = '주택 구조, 연령, 난방설비 등 성능'
data.loc[data.D5102==5, 'D5102'] = '본인 또는 배우자의 직장과의 접근성'
data.loc[data.D5102==6, 'D5102'] = '편리한 대중교통'
data.loc[data.D5102==7, 'D5102'] = '자동차 이용 편리'
data.loc[data.D5102==8, 'D5102'] = '자녀의 교육 또는 보육 환경'
data.loc[data.D5102==9, 'D5102'] = '조용한 주거 지역'
data.loc[data.D5102==10, 'D5102'] = '편의시설 이용과 가까워서'
data.loc[data.D5102==11, 'D5102'] = '문화·여가시설(공연, 전시 등) 이용'
data.loc[data.D5102==12, 'D5102'] = '부모님, 자녀 등 가족과 가까워서'
data.loc[data.D5102==13, 'D5102'] = '자연환경(녹지, 하천 등)이 좋아서'
data.loc[data.D5102==14, 'D5102'] = '기타'

data.loc[data.D6==1, 'D6'] = '아파트'
data.loc[data.D6==2, 'D6'] = '다세대·연립'
data.loc[data.D6==3, 'D6'] = '다가구주택'
data.loc[data.D6==4, 'D6'] = '단독주택'
data.loc[data.D6==5, 'D6'] = '오피스텔'
data.loc[data.D6==6, 'D6'] = '주상복합'
data.loc[data.D6==7, 'D6'] = '상가주택'
data.loc[data.D6==8, 'D6'] = '점포주택'
data.loc[data.D6==9, 'D6'] = '고시원'
data.loc[data.D6==10, 'D6'] = '기숙사'
data.loc[data.D6==11, 'D6'] = '기타'

data.loc[data.D7==1, 'D7'] = '자가'
data.loc[data.D7==2, 'D7'] = '전세'
data.loc[data.D7==3, 'D7'] = '전세보증금을 조금 낮추고 약간의 월세 (반전세)'
data.loc[data.D7==4, 'D7'] = '전세보증금은 조금 내고 월세를 많이'
data.loc[data.D7==5, 'D7'] = '보증금 없이 계약기간 내 전체 월세를 한 번에 지급'
data.loc[data.D7==6, 'D7'] = '기타'

data.head()

## Show whole data frame
# with pd.option_context('display.max_columns', None): 
#     display(data)
# Out:
#    ID  SQ1   SQ2 SQ21  SQ3       SQ31     SQ4  SQ41  SQ42   A1  ...  \
# 0   1    1  1980  30대    2    성남시 수정구  201405  2014     5  가구주  ...
# 1   2    2  1981  30대    2   고양시 일산동구  201204  2012     4  배우자  ...
# 2   3    2  1977  30대    1        강북구  199505  1995     5  배우자  ...
# 3   4    2  1993  20대    2  인천광역시 계양구  201506  2015     6   자녀  ...
# 4   5    2  1973  40대    1        송파구  200510  2005    10  배우자  ...
#
#                     D7   D8  DQ1  DQ2  DQ3  DQ4 DQ5a1 DQ5a2 DQ5a3        wt
# 0  전세보증금은 조금 내고 월세를 많이  2.0    1    4    4    4    서울    서초    서초  1.000000
# 1                   자가  5.0    2    4    2    1   NaN   NaN   NaN  1.000000
# 2                  NaN  NaN    2    4    4    3    서울    강북    수유  0.857143
# 3                   자가  4.0    1    3    3    5    서울    성북    돈암  1.000000
# 4                  NaN  NaN    2    2    2    1   NaN   NaN   NaN  1.454545
#
# [5 rows x 65 columns]

# %%
# edit columns name

data.columns =["ID", "성별", "출생연도", "연령대", "거주지역", "거주지역_시_구", "거주시작 년월", "거주시작 년", "거주시작 월", "가구주와의 관계",
           "가구 구성-미취학아동", "가구 구성-초등학생", "가구 구성-중고등학생", "가구 구성-19-39세", "가구 구성-40-64세", "가구 구성-65세 이상",
            '월 평균 소득', '현 거주 주택 유형', '현 거주 주택 면적', '현 거주 주택 점유형태', '주택 가격', '주택 보증금', '주택 월세', 
            '현 주택 외 본인 및 배우자 소유 주택 유무', '현 주택 외 본인 및 배우자 소유 주택 위치(서울)', 
            '현 주택 외 본인 및 배우자 소유 주택 위치(경기,인천)', '현 주택 외 본인 및 배우자 소유 주택 위치(비수도권)', 
            '현 주택 외 본인 및 배우자 소유 주택 수 (1)', '현 주택 외 본인 및 배우자 소유 주택 수 (2)', 
            '현 주택 외 본인 및 배우자 소유 주택 수 (3)', '주택 가격 전망(5년내)', '주택 가격 전망(5년이후)', '부동산_및_금융자산_선호_여부',
            '부동산 선호 이유 1순위', '부동산 선호 이유 2순위', '금융자산 선호 이유 1순위', '금융자산 선호 이유 2순위', 
            '주택_소유_및_임대_선호도', '주택_소유하고_싶은_이유_1순위', '주택_소유하고_싶은_이유_2순위', '주택_임대하고_싶은_이유_1순위',
            '주택_임대하고_싶은_이유_2순위', '10년 내 이사 경험','5년 내 이사 의향','5년 내 이사하고 싶은 이유 1순위', 
            '5년 내 이사하고 싶은 이유 2순위', '5년 내 이사 지역','희망_이사_지역','이사하고_싶은_지역_장점_1순위',
            '이사하고_싶은_지역_장점_2순위', '이사하고_싶은_지역_장점_3순위', '이사하고_싶은_지역_단점_1순위','이사하고_싶은_지역_단점_2순위',
            '이사하고_싶은_지역_단점_3순위', '원하는_주택_유형', '원하는_주택_점유_형태','원하는_주택_크기', '결혼 상태', '최종학력', '근로형태',
            '통근_통학 시간', '통근_통학지_시(군)','통근_통학지_구', '통근_통학지_동', 'wt']

data.head()

## Show whole data frame 
# with pd.option_context('display.max_columns', None): 
#     display(data)
# Out:
#    ID  성별  출생연도  연령대  거주지역   거주지역_시_구  거주시작 년월  거주시작 년  거주시작 월 가구주와의 관계  ...  \
# 0   1   1  1980  30대     2    성남시 수정구   201405    2014       5      가구주  ...
# 1   2   2  1981  30대     2   고양시 일산동구   201204    2012       4      배우자  ...
# 2   3   2  1977  30대     1        강북구   199505    1995       5      배우자  ...
# 3   4   2  1993  20대     2  인천광역시 계양구   201506    2015       6       자녀  ...
# 4   5   2  1973  40대     1        송파구   200510    2005      10      배우자  ...
#
#           원하는_주택_점유_형태  원하는_주택_크기  결혼 상태  최종학력  근로형태  통근_통학 시간 통근_통학지_시(군)  \
# 0  전세보증금은 조금 내고 월세를 많이        2.0      1     4     4         4          서울
# 1                   자가        5.0      2     4     2         1         NaN
# 2                  NaN        NaN      2     4     4         3          서울
# 3                   자가        4.0      1     3     3         5          서울
# 4                  NaN        NaN      2     2     2         1         NaN
#
#   통근_통학지_구 통근_통학지_동        wt
# ...

# %%
# personel information

data_personel = data[["성별", "출생연도", "연령대", "거주지역", "거주지역_시_구",'결혼 상태', '최종학력', '근로형태']]
data_personel.head()
# Out:
#    성별  출생연도  연령대  거주지역   거주지역_시_구  결혼 상태  최종학력  근로형태
# 0   1  1980  30대     2    성남시 수정구      1     4     4
# 1   2  1981  30대     2   고양시 일산동구      2     4     2
# 2   2  1977  30대     1        강북구      2     4     4
# 3   2  1993  20대     2  인천광역시 계양구      1     3     3
# 4   2  1973  40대     1        송파구      2     2     2

# %%
# Age group counting

data_personel.연령대.value_counts()
# Out:
# 40대    666
# 30대    647
# 50대    623
# 20대    591
# 60대    473
# Name: 연령대, dtype: int64

# %%
# residence grouping

data_personel.거주지역_시_구.value_counts()
# Out:
# 송파구          103
# 강남구           98
# 강서구           98
# 노원구           95
# 관악구           93
# 은평구           92
# 강동구           88
# 성북구           87
# 양천구           87
# 구로구           86
# 서초구           85
# 중랑구           84
# 영등포           81
# 동작구           81
# 마포구           80
# 동대문           77
# 광진구           76
# 강북구           74
# 도봉구           74
# 성동구           70
# 서대문           70
# 금천구           63
# 용산구           62
# 남양주시          58
# 인천광역시 부평구     55
# 성남시 분당구       51
# 종로구           49
# 의정부시          49
# 부천시 원미구       48
# 고양시 덕양구       48
# 중구            47
# 안양시 동안구       44
# 광명시           43
# 용인시 기흥구       43
# 인천광역시 계양구     42
# 김포시           42
# 용인시 수지구       41
# 고양시 일산동구      40
# 고양시 일산서구      40
# 성남시 중원구       38
# 군포시           38
# 안양시 만안구       38
# 성남시 수정구       37
# 부천시 소사구       37
# 양주시           33
# 부천시 오정구       31
# 구리시           30
# 하남시           28
# 의왕시           28
# 과천시           18
# Name: 거주지역_시_구, dtype: int64

# %%
data_info=data[['연령대','부동산_및_금융자산_선호_여부','주택_소유_및_임대_선호도', '주택_소유하고_싶은_이유_1순위', '주택_소유하고_싶은_이유_2순위', '주택_임대하고_싶은_이유_1순위','주택_임대하고_싶은_이유_2순위', '이사하고_싶은_지역_장점_1순위', '이사하고_싶은_지역_장점_2순위', '이사하고_싶은_지역_장점_3순위', '이사하고_싶은_지역_단점_1순위','이사하고_싶은_지역_단점_2순위','이사하고_싶은_지역_단점_3순위' ]]
data_info.head()
# Out:
#    연령대 부동산_및_금융자산_선호_여부  주택_소유_및_임대_선호도  주택_소유하고_싶은_이유_1순위  주택_소유하고_싶은_이유_2순위  \
# 0  30대             잘 모름               2                NaN                NaN
# 1  30대         금융자산이 낫다               1                1.0                2.0
# 2  30대         금융자산이 낫다               1                1.0                2.0
# 3  20대          부동산이 낫다               1                2.0                7.0
# 4  40대         금융자산이 낫다               1                1.0                7.0
#
#    주택_임대하고_싶은_이유_1순위  주택_임대하고_싶은_이유_2순위    이사하고_싶은_지역_장점_1순위  \
# 0                1.0                3.0    고향 등 지역의 익숙함, 친근함
# 1                NaN                NaN  본인 또는 배우자의 직장과의 접근성
# 2                NaN                NaN                  NaN
# 3                NaN                NaN    고향 등 지역의 익숙함, 친근함
# 4                NaN                NaN                  NaN
#
#   이사하고_싶은_지역_장점_2순위     이사하고_싶은_지역_장점_3순위  이사하고_싶은_지역_단점_1순위  \
# 0         자동차 이용 편리  문화·여가시설(공연, 전시 등) 이용                6.0
# ...

# %%
data_age_ans = data[['연령대','원하는_주택_유형', '원하는_주택_점유_형태','원하는_주택_크기', '이사하고_싶은_지역_장점_1순위', '이사하고_싶은_지역_단점_1순위', '희망_이사_지역']]
data_age_ans.head()
# Out:
#    연령대 원하는_주택_유형         원하는_주택_점유_형태  원하는_주택_크기    이사하고_싶은_지역_장점_1순위  \
# 0  30대     다가구주택  전세보증금은 조금 내고 월세를 많이        2.0    고향 등 지역의 익숙함, 친근함
# 1  30대       아파트                   자가        5.0  본인 또는 배우자의 직장과의 접근성
# 2  30대       NaN                  NaN        NaN                  NaN
# 3  20대       아파트                   자가        4.0    고향 등 지역의 익숙함, 친근함
# 4  40대       NaN                  NaN        NaN                  NaN
#
#    이사하고_싶은_지역_단점_1순위 희망_이사_지역
# 0                6.0      NaN
# 1                1.0      NaN
# 2                NaN      NaN
# 3                9.0      NaN
# 4                NaN      NaN

# %%
# Setting age 

age_2 = data_age_ans[data_age_ans.연령대=='20대']
age_3 = data_age_ans[data_age_ans.연령대=='30대']
age_4 = data_age_ans[data_age_ans.연령대=='40대']
age_5 = data_age_ans[data_age_ans.연령대=='50대']
age_6 = data_age_ans[data_age_ans.연령대=='60대']

# %%
# Data Frame of favorite local reason 

age_2_favorite_loc_res = age_2.이사하고_싶은_지역_장점_1순위.value_counts()
age_3_favorite_loc_res = age_3.이사하고_싶은_지역_장점_1순위.value_counts() 
age_4_favorite_loc_res = age_4.이사하고_싶은_지역_장점_1순위.value_counts()
age_5_favorite_loc_res = age_5.이사하고_싶은_지역_장점_1순위.value_counts()
age_6_favorite_loc_res = age_6.이사하고_싶은_지역_장점_1순위.value_counts()

age_2_favorite_loc_res = pd.DataFrame(age_2_favorite_loc_res)
age_3_favorite_loc_res = pd.DataFrame(age_3_favorite_loc_res)
age_4_favorite_loc_res = pd.DataFrame(age_4_favorite_loc_res)
age_5_favorite_loc_res = pd.DataFrame(age_5_favorite_loc_res)
age_6_favorite_loc_res = pd.DataFrame(age_6_favorite_loc_res)

# age_2_favorite_loc_res
# age_3_favorite_loc_res
# age_4_favorite_loc_res
# age_5_favorite_loc_res
# age_6_favorite_loc_res

# %%
## favorite local reason bar plot 

# chart Data Frame
chart_fav_loc_age_2 = pd.DataFrame(age_2_favorite_loc_res)
chart_fav_loc_age_3 = pd.DataFrame(age_3_favorite_loc_res)
chart_fav_loc_age_4 = pd.DataFrame(age_4_favorite_loc_res)
chart_fav_loc_age_5 = pd.DataFrame(age_5_favorite_loc_res)
chart_fav_loc_age_6 = pd.DataFrame(age_6_favorite_loc_res)

# bar plot 
import matplotlib.pyplot as plt

plt.rc('font', family = 'AppleGothic')
an_age2 = chart_fav_loc_age_2.plot(kind='bar', title='20대')
an_age3 = chart_fav_loc_age_3.plot(kind='bar', title='30대')
an_age4 = chart_fav_loc_age_4.plot(kind='bar', title='40대')
an_age5 = chart_fav_loc_age_5.plot(kind='bar', title='50대')
an_age6 = chart_fav_loc_age_6.plot(kind='bar', title='60대')

# %%
fav_house_chart_data_age_2 = age_2.원하는_주택_유형.value_counts()
fav_house_chart_data_age_3 = age_3.원하는_주택_유형.value_counts()
fav_house_chart_data_age_4 = age_4.원하는_주택_유형.value_counts()
fav_house_chart_data_age_5 = age_5.원하는_주택_유형.value_counts()
fav_house_chart_data_age_6 = age_6.원하는_주택_유형.value_counts()

fav_house_chart_data_age_2 = pd.DataFrame(fav_house_chart_data_age_2)
fav_house_chart_data_age_3 = pd.DataFrame(fav_house_chart_data_age_3)
fav_house_chart_data_age_4 = pd.DataFrame(fav_house_chart_data_age_4)
fav_house_chart_data_age_5 = pd.DataFrame(fav_house_chart_data_age_5)
fav_house_chart_data_age_6 = pd.DataFrame(fav_house_chart_data_age_6)

# fav_house_chart_data_age_2
# fav_house_chart_data_age_3
# fav_house_chart_data_age_4
# fav_house_chart_data_age_5
# fav_house_chart_data_age_6

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')
fav_house_chart_data_age_2.plot(kind='bar', title='20대', color = 'orange')
fav_house_chart_data_age_2.plot(kind='bar', title='30대', color = 'orange')
fav_house_chart_data_age_2.plot(kind='bar', title='40대', color = 'orange')
fav_house_chart_data_age_2.plot(kind='bar', title='50대', color = 'orange')
fav_house_chart_data_age_2.plot(kind='bar', title='60대', color = 'orange')
